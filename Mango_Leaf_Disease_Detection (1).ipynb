# %% [markdown]
# Importing all the required libraries

# %%
# !pip install ultralytics==8.0.196
# !pip install roboflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.1/631.1 kB 8.0 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %% [markdown]
# Colllecting the file directory.

# %%
import os
location = os.getcwd()          # COLLECTING THE LOCATION
print(location)
# Out:
# /content

# %% [markdown]
# Importing YOLO V8 model for object detection.

# %%
from ultralytics import YOLO

# %% [markdown]
# Importing Custom Dataset from Roboflow.
#
# ```
# # This is formatted as code
# ```

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="Enter your api id here")
project = rf.workspace("robotele").project("leaf-detection-ljsxj")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Leaf-Detection-1 in yolov8:: 100%|██████████| 282/282 [00:00<00:00, 4894.82it/s]

# %% [markdown]
# Training the dataset.

# %%
# %cd {location}   # TO CHANGE THE DICTIONARY
# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=70 imgsz=800 plots=True
# Out:
# [Errno 2] No such file or directory: '/content # TO CHANGE THE DICTIONARY'
# /content
# ...
# 100% 21.5M/21.5M [00:00<00:00, 332MB/s]
# New https://pypi.org/project/ultralytics/8.2.51 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# Testing the dataset.

# %%
# %cd {location}
# !yolo task=detect mode=predict model={location}/runs/detect/train/weights/best.pt conf=0.25 source="l10.png"
# Out:
# /content
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/l10.png: 800x800 1 Unhealthy Leaf, 34.2ms
# Speed: 9.6ms preprocess, 34.2ms inference, 777.6ms postprocess per image at shape (1, 3, 800, 800)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
